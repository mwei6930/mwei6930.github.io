# %% [raw]
# ---
# title: Deep Learning Guideline
# format:
#   html:
#     toc: true
#     toc-depth: 5
#     theme: cosmo
#     # code-fold: true
# jupyter: python
# ---

# %% [markdown]
# # Deep Learning Guideline
#
# This notebook is a navigation guideline for the split Deep Learning notes. The complete original notebook is preserved as `Deep-Learning-full.ipynb`.
#
# ## Split Sections
#
# 1. [What is Deep Learning](01-what-is-deep-learning.html)
# 2. [Neural Networks Basics](02-neural-networks-basics.html)
# 3. [Training Neural Networks](03-training-neural-networks.html)
# 4. [Core Architectures](04-core-architectures.html)
