# %% [raw]
# ---
# title: Deep Learning - Core Architectures
# format:
#   html:
#     toc: true
#     toc-depth: 5
#     theme: cosmo
#     # code-fold: true
# jupyter: python
# ---

# %% [markdown]
# # Deep Learning: Core Architectures
#
# [Back to Deep Learning guideline](Deep-Learning.html)

# %% [markdown]
# ## Core Architectures
# ### Feedforward Neural Networks
# ### Convolutional Neural Networks (CNN)
# ### Recurrent Neural Networks (RNN)
# ### LSTM and GRU
# ### Autoencoders
# ### Attention and Transformers
