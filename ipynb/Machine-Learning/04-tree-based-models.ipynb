# %% [raw]
# ---
# title: Machine Learning - Tree Based Models
# format:
#   html:
#     toc: true
#     toc-depth: 5
#     theme: cosmo
#     # code-fold: true
# jupyter: python
# ---

# %% [markdown]
# [Back to Machine Learning guideline](Machine Learning.html)

# %% [markdown]
# ## **Tree Based Models**
