# %% [raw]
# ---
# title: Statistics - Correlation & Association
# format:
#   html:
#     toc: true
#     toc-depth: 5
#     theme: cosmo
#     # code-fold: true
# jupyter: python
# ---

# %% [markdown]
# [Back to Statistics guideline](Statistics.html)

# %% [markdown]
# ### **Correlation & Association**
