# %% [raw]
# ---
# title: Statistics - Sampling & Estimation
# format:
#   html:
#     toc: true
#     toc-depth: 5
#     theme: cosmo
#     # code-fold: true
# jupyter: python
# ---

# %% [markdown]
# [Back to Statistics guideline](Statistics.html)

# %% [markdown]
# ### **Sampling & Estimation**
