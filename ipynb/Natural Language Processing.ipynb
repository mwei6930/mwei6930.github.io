# %% [raw]
# ---
# title: "Natural Language Processing"
# format:
#   html:
#     toc: true
#     toc-depth: 5
#     theme: cosmo
#     # code-fold: true
# jupyter: python
# ---

# %% [markdown]
# ## **Text Representation**

# %% [markdown]
# ## **Evaluation**
