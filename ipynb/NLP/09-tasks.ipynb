# %% [raw]
# ---
# title: "Natural Language Processing: NLP Tasks"
# format:
#   html:
#     toc: true
#     toc-depth: 5
#     theme: cosmo
#     # code-fold: true
# jupyter: python
# ---

# %% [markdown]
# [Back to NLP guideline](Natural-Language-Processing.html)

# %% [markdown]
# ## **NLP Tasks**
# ### Sequence Labeling
# #### Name Entity Recognition(NER)
# #### POS Tagging
# #### Word Segmentation
# ### Classification
# #### Sentiment Analysis
# #### Intent Detection
# #### Topic Classification
# ### Sentence Relationship
# #### Semantic Textual Similarity(STS)
# #### Natural Language Inference(NLI) / Recongnizing Textual Entailment(RTE)
# ### **Seq2Seq / Generation**
# #### Machine Translation
# #### Summarization
# ### Information Extraction
