# %% [raw]
# ---
# title: Natural Language Processing Guideline
# lang: en
# format:
#   html:
#     toc: true
#     toc-depth: 5
#     theme: cosmo
#     # code-fold: true
# jupyter: python
# ---

# %% [markdown]
# <div class="blog-language-switch" role="group" aria-label="Article language">
# <span aria-current="page">English</span>
# <a href="/ipynb/zh-CN/NLP/Natural-Language-Processing.html" lang="zh-CN" hreflang="zh-CN">中文</a>
# </div>
#
# Natural Language Processing (NLP) is a major subfield of AI that focuses on enabling computers to understand, analyze, and generate human language. Unlike structured data, natural language is highly contextual and ambiguous: the same expression may carry different meanings across speakers, domains, and situations. A complete NLP system therefore needs more than a model. It also needs a clear account of language, carefully constructed data, an appropriate input-output formulation, a training strategy, and an evaluation protocol that reflects the intended use.
#
# The chapters below follow the dependency of an NLP project rather than the historical order in which methods appeared. Language and data come first; tokenisation turns text into model units; representation and modeling define what can be learned; training and evaluation determine whether learning succeeds; benchmarks make research claims comparable; tasks connect methods to applications; and the final chapters address risk and complete system design.
#
# ```text
# language and data
# -> tokenisation
# -> representation
# -> modeling
# -> training
# -> evaluation and comparison
# -> tasks and applications
# -> responsible production systems
# ```
#
# ## **Sections** {#sections}
#
# ### **Language and Representation** {#language-and-representation}
#
# These chapters establish what language data contains and how raw text becomes computational input.
#
# 1. [Foundations and Core Components of NLP Systems](01-core-components.html)
# 2. [Tokenisation](02-tokenisation.html)
# 3. [Text Representation](03-text-representation.html)
#
# ### **Model Development** {#model-development}
#
# These chapters connect task formulations to architectures, learning objectives, optimization, and evidence-based evaluation.
#
# 4. [Modeling in NLP](04-modeling.html)
# 5. [Training and Optimization](05-training-optimization.html)
# 6. [Evaluation in NLP](06-evaluation.html)
#
# ### **Research and Applications** {#research-and-applications}
#
# These chapters explain how systems are compared and how language problems become concrete prediction, retrieval, generation, and affective-computing tasks.
#
# 7. [Baselines, Benchmarks, and State of the Art in NLP](07-baseline.html)
# 8. [NLP Tasks and Applications](08-tasks-and-applications.html)
#
# ### **Responsible Systems** {#responsible-systems}
#
# These chapters move beyond isolated model quality to risks, governance, retrieval, tools, deployment, and complete system behavior.
#
# 9. [Challenges, Risks, Ethics, and Safety](09-challenges.html)
# 10. [Modern NLP Systems](10-modern-systems.html)
