# %% [raw]
# ---
# title: NLP - Training & Optimization
# format:
#   html:
#     toc: true
#     toc-depth: 5
#     theme: cosmo
#     # code-fold: true
# jupyter: python
# ---

# %% [markdown]
# # Natural Language Processing: Training & Optimization
#
# [Back to NLP guideline](Natural-Language-Processing.html)

# %% [markdown]
# ## **Training & Optimization**
