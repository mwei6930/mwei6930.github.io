# %% [raw]
# ---
# title: "Natural Language Processing: Evaluation in NLP"
# format:
#   html:
#     toc: true
#     toc-depth: 5
#     theme: cosmo
#     # code-fold: true
# jupyter: python
# ---

# %% [markdown]
# [Back to NLP guideline](Natural-Language-Processing.html)

# %% [markdown]
# ## **Evaluation in NLP**
