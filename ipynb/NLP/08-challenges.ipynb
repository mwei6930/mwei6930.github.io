# %% [raw]
# ---
# title: "Natural Language Processing: Chanllenges"
# format:
#   html:
#     toc: true
#     toc-depth: 5
#     theme: cosmo
#     # code-fold: true
# jupyter: python
# ---

# %% [markdown]
# [Back to NLP guideline](Natural-Language-Processing.html)

# %% [markdown]
# ## **Chanllenges**
