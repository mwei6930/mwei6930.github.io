# %% [raw]
# ---
# title: "Data Structures and Algorithms: Searching, Sorting, and Divide-and-Conquer"
# format:
#   html:
#     toc: true
#     toc-depth: 5
#     theme: cosmo
#     # code-fold: true
# jupyter: python
# ---

# %% [markdown]
# [Back to Data Structures and Algorithms guideline](Data-Structure&Algorithm.html)

# %% [markdown]
# ## **Searching, Sorting, and Divide-and-Conquer**
#
# ### **Binary Search**
#
# ### **Boundary Search Templates**
#
# ### **Sorting Properties and Lower Bounds**
#
# ### **Elementary Sorting Algorithms**
#
# ### **Merge Sort**
#
# ### **Quick Sort**
#
# ### **Heap Sort**
#
# ### **Divide-and-Conquer Design**
#
# ### **Recurrence Analysis**
#
# ### **Recursion Trees and the Master Theorem**
#
# ### **Quickselect and Randomized Pivots**
#
# ### **Comparison and Selection**
